# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("city_weather_data.csv")

# %% [markdown]
# ### basic pandas function

# %%
data.shape
# Out:
# (10, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        10 non-null     object
#  1   temp        10 non-null     float64
#  2   like_temp   10 non-null     float64
#  3   Humidity    10 non-null     int64
#  4   Pressure    10 non-null     int64
#  5   Weather     10 non-null     object
#  6   Wind_speed  10 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 692.0+ bytes

# %%
data.head()
# Out:
#             City  Temperature (°C)  Feels Like (°C)  Humidity (%)  \
# 0       New York             23.35            23.54            69
# 1  San Francisco             23.30            23.30            62
# 2         London             21.78            21.76            67
# 3          Tokyo             15.90            15.50            75
# 4          Delhi             30.05            31.28            51
#
#    Pressure (hPa)               Weather  Wind Speed (m/s)
# 0            1002            Few clouds              7.20
# 1            1015            Few clouds              3.60
# 2            1018         Broken clouds              4.12
# 3            1005  Heavy intensity rain              9.77
# 4             996                  Haze              1.03

# %%
data.tail(
)
# Out:
#         City  Temperature (°C)  Feels Like (°C)  Humidity (%)  Pressure (hPa)  \
# 5      Cairo             26.42            26.42            50            1009
# 6  Sao Paulo             17.63            17.35            73            1021
# 7     Sydney             12.98            12.53            84            1027
# 8    Toronto             24.59            24.31            46            1000
# 9      Paris             28.03            28.22            47            1018
#
#            Weather  Wind Speed (m/s)
# 5        Clear sky              5.66
# 6       Few clouds              5.14
# 7  Overcast clouds              3.60
# 8  Overcast clouds              1.79
# 9        Clear sky              3.09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              10 non-null     object
#  1   Temperature (°C)  10 non-null     float64
#  2   Feels Like (°C)   10 non-null     float64
#  3   Humidity (%)      10 non-null     int64
#  4   Pressure (hPa)    10 non-null     int64
#  5   Weather           10 non-null     object
#  6   Wind Speed (m/s)  10 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 692.0+ bytes

# %%
data.describe()
# Out:
#        Temperature (°C)  Feels Like (°C)  Humidity (%)  Pressure (hPa)  \
# count         10.000000        10.000000     10.000000       10.000000
# mean          22.403000        22.421000     62.400000     1011.100000
# std            5.446834         5.826944     13.301629       10.202941
# min           12.980000        12.530000     46.000000      996.000000
# 25%           18.667500        18.452500     50.250000     1002.750000
# 50%           23.325000        23.420000     64.500000     1012.000000
# 75%           25.962500        25.892500     72.000000     1018.000000
# max           30.050000        31.280000     84.000000     1027.000000
#
#        Wind Speed (m/s)
# count         10.000000
# mean           4.500000
# std            2.581033
# min            1.030000
# 25%            3.217500
# 50%            3.860000
# 75%            5.530000
# max            9.770000

# %%
data.isnull().sum()
# Out:
# City                0
# Temperature (°C)    0
# Feels Like (°C)     0
# Humidity (%)        0
# Pressure (hPa)      0
# Weather             0
# Wind Speed (m/s)    0
# dtype: int64

# %%
data.value_counts()
# Out:
# City           Temperature (°C)  Feels Like (°C)  Humidity (%)  Pressure (hPa)  Weather               Wind Speed (m/s)
# Cairo          26.42             26.42            50            1009            Clear sky             5.66                1
# Delhi          30.05             31.28            51            996             Haze                  1.03                1
# London         21.78             21.76            67            1018            Broken clouds         4.12                1
# New York       23.35             23.54            69            1002            Few clouds            7.20                1
# Paris          28.03             28.22            47            1018            Clear sky             3.09                1
# San Francisco  23.30             23.30            62            1015            Few clouds            3.60                1
# ...

# %%
data.nunique()
# Out:
# City                10
# Temperature (°C)    10
# Feels Like (°C)     10
# Humidity (%)        10
# Pressure (hPa)       9
# Weather              6
# Wind Speed (m/s)     9
# dtype: int64

# %%
data.columns
# Out:
# Index(['City', 'Temperature (°C)', 'Feels Like (°C)', 'Humidity (%)',
#        'Pressure (hPa)', 'Weather', 'Wind Speed (m/s)'],
#       dtype='object')

# %%
data=data.rename(columns={"Temperature (°C)":"temp",
"Feels Like (°C)":"like_temp",
"Humidity (%)":"Humidity",
"Pressure (hPa)":"Pressure",
"Wind Speed (m/s)":"Wind_speed"})

# %%
data.duplicated().all()
# Out:
# np.False_

# %% [markdown]
# ### data visulization -using the seaborn

# %%
data.dtypes
# Out:
# City                 object
# Temperature (°C)    float64
# Feels Like (°C)     float64
# Humidity (%)          int64
# Pressure (hPa)        int64
# Weather              object
# Wind Speed (m/s)    float64
# dtype: object

# %%
data.head(1)
# Out:
#        City   temp  like_temp  Humidity  Pressure     Weather  Wind_speed
# 0  New York  23.35      23.54        69      1002  Few clouds         7.2

# %% [markdown]
# ### univerate analysis

# %%
plt.figure(figsize=(10,10))
sns.barplot(data ,x="City",y="temp")
# Out:
# <Axes: xlabel='City', ylabel='temp'>

# %%
sns.lineplot(data  ,x="temp" ,y="Wind_speed")
# Out:
# <Axes: xlabel='temp', ylabel='Wind_speed'>

# %%
sns.lineplot(data,x="temp" ,y="Pressure")
# Out:
# <Axes: xlabel='temp', ylabel='Pressure'>

# %%
sns.distplot(data["temp"])
# Out:
# /tmp/ipython-input-55-508010777.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["temp"])
# <Axes: xlabel='temp', ylabel='Density'>

# %%
sns.distplot(data["Pressure"])
# Out:
# /tmp/ipython-input-57-3034386467.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Pressure"])
# <Axes: xlabel='Pressure', ylabel='Density'>

# %%
sns.scatterplot(data , x="Pressure" , y="temp" ,hue="City")
# Out:
# <Axes: xlabel='Pressure', ylabel='temp'>

# %%
sns.catplot(data ,x="Pressure" , y="temp"  )

# %%
sns.boxplot(data["Pressure"])
# Out:
# <Axes: ylabel='Pressure'>

# %%
sns.violinplot(data["temp"])
# Out:
# <Axes: ylabel='temp'>

# %%
sns.distplot(data["temp"])
# Out:
# /tmp/ipython-input-64-508010777.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["temp"])
# <Axes: xlabel='temp', ylabel='Density'>

# %%
sns.pairplot(data)

# %%
sns.regplot(data ,x="like_temp" , y="Pressure")
# Out:
# <Axes: xlabel='like_temp', ylabel='Pressure'>

# %%
sns.regplot(data ,x="Humidity" , y="Pressure")
# Out:
# <Axes: xlabel='Humidity', ylabel='Pressure'>

# %%
sns.jointplot(data, x="like_temp" , y="Pressure", )

# %%
sns.displot(data, bins=10 , x="like_temp" )

# %%
data=data.drop(columns="City")

# %%
data
# Out:
#     temp  like_temp  Humidity  Pressure               Weather  Wind_speed
# 0  23.35      23.54        69      1002            Few clouds        7.20
# 1  23.30      23.30        62      1015            Few clouds        3.60
# 2  21.78      21.76        67      1018         Broken clouds        4.12
# 3  15.90      15.50        75      1005  Heavy intensity rain        9.77
# 4  30.05      31.28        51       996                  Haze        1.03
# 5  26.42      26.42        50      1009             Clear sky        5.66
# 6  17.63      17.35        73      1021            Few clouds        5.14
# 7  12.98      12.53        84      1027       Overcast clouds        3.60
# 8  24.59      24.31        46      1000       Overcast clouds        1.79
# 9  28.03      28.22        47      1018             Clear sky        3.09

# %%
data1=data.drop(columns=["Weather"])

# %%
sns.heatmap(data1)
# Out:
# <Axes: >
